# %% [markdown]
# 1. 下載 + 安裝 VMware Workstation 16 Player<br>
# https://www.vmware.com/products/workstation-player/workstation-player-evaluation.html<br><br>
#
# 2. 下載 + 解壓縮 Kali Linux + Metasploitable<br>
# https://drive.google.com/file/d/1QZY_QIF3BgENmIBR-6hTKMZRDcT6Uwz0/view?usp=sharing<br>
# https://drive.google.com/file/d/1o-ArGgDPMDJpFIndl5DHv669C6N3dDdC/view?usp=sharing<br><br>
#
# 3. 開 Vmware Workstation 16 Player，選 Open a Virtual Machine，去解壓縮了的 Kali Linux 檔，選 Kali-Linux-2020.4-vmware-amd64<br>
# <img src="attachment:one.png" style="width:500px;"/>
#
# 4. 選多一次 Open a Virtual Machine，去解壓縮了的 Metasploitable 檔，選 Metasploitable
